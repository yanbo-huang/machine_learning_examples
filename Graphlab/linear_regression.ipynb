# %% [markdown]
# ###Linear Regression with Graphlab

# %%
import graphlab
# Out:
# A newer version of GraphLab Create (v1.8.1) is available! Your current version is v1.7.1.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.

# %%
#load data
data = graphlab.SFrame.read_csv("Downloads/MachineLearning-master/Example Data/OLS_Regression_Example_3.csv")
# Out:
# [INFO] 1454690205 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to /Users/wbcha/.graphlab/anaconda/lib/python2.7/site-packages/certifi/cacert.pem
# 1454690205 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to B.Wang-6@student.tudelft.nl and will expire on September 21, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-85394 - Server binary: /Users/wbcha/.graphlab/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1454690205.log
# [INFO] GraphLab Server Version: 1.7.1
# PROGRESS: Finished parsing file /Users/wbcha/Downloads/MachineLearning-master/Example Data/OLS_Regression_Example_3.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.088282 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,float,float]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /Users/wbcha/Downloads/MachineLearning-master/Example Data/OLS_Regression_Example_3.csv
# PROGRESS: Parsing completed. Parsed 10000 lines in 0.024214 secs.

# %%
data.head()
data.tail()
# Out:
# Columns:
# 	Gender	str
# 	Height	float
# 	Weight	float
#
# Rows: 10
#
# Data:
# +--------+---------------+---------------+
# | Gender |     Height    |     Weight    |
# +--------+---------------+---------------+
# | Female | 63.1794982498 | 141.266099582 |
# | Female | 62.6366749338 | 102.853563215 |
# | Female | 62.0778316937 | 138.691680276 |
# | Female | 60.0304337716 | 97.6874322555 |
# | Female | 59.0982500313 | 110.529685683 |
# | Female | 66.1726521478 | 136.777454183 |
# | Female | 67.0671546491 | 170.867905891 |
# | Female | 63.8679922138 | 128.475318784 |
# | Female | 69.0342431307 | 163.852461347 |
# | Female | 61.9442458795 | 113.649102675 |
# +--------+---------------+---------------+
# [10 rows x 3 columns]

# %%
#Set visualize target to ipython notebook
graphlab.canvas.set_target("ipynb")

# %%
#Replace Us metrics with cm and kilo's
height_transform = lambda x:x * 2.54
weight_transform = lambda x:x * 0.45359237

# %%
data['Height'] = height_transform(data['Height'])
data['Weight'] = weight_transform(data['Weight'])

# %%
#view data
data.show(view="Scatter Plot", x = "Height", y = "Weight")

# %%
#split data into train and test
train_data, test_data = data.random_split(0.8, seed = 1)

# %%
#train a linear model
lm_model = graphlab.linear_regression.create(train_data, target="Weight", features=['Gender', 'Height'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
#
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 7616
# PROGRESS: Number of features          : 2
# PROGRESS: Number of unpacked features : 2
# PROGRESS: Number of coefficients    : 3
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Validation-max_error | Training-rmse | Validation-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# PROGRESS: | 1         | 2        | 1.022818     | 19.999442          | 12.949690            | 4.543539      | 4.445043        |
# PROGRESS: +-----------+----------+--------------+--------------------+----------------------+---------------+-----------------+
# PROGRESS: SUCCESS: Optimal solution found.
# PROGRESS:

# %%
#evaluate based on test_data
lm_prediction = lm_model.predict(test_data)
lm_prediction.head(5)
# Out:
# dtype: float
# Rows: 5
# [79.47349575427748, 69.83406534090832, 85.49339849495988, 86.56579723717985, 81.83906623178873]

# %%
lm_model.evaluate(test_data) ##we can see max error and rmse error

# %%
#we can get that rmse = 4.54
#predict weight based on male, height 170, female 170
#firstly construct a SFrame
predict_data = graphlab.SFrame({'Gender':['Male','Female'], "Height":[170,170]})

# %%
predict_data
# Out:
# Columns:
# 	Gender	str
# 	Height	int
#
# Rows: 2
#
# Data:
# +--------+--------+
# | Gender | Height |
# +--------+--------+
# |  Male  |  170   |
# | Female |  170   |
# +--------+--------+
# [2 rows x 2 columns]

# %%
lm_model.predict(predict_data)#predict male of 170 is 79.1kg, predict female of 170 is 70.35kg
# Out:
# dtype: float
# Rows: 2
# [79.12321074864113, 70.34906162334039]
